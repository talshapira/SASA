# %%
ipsource_dict = {0: 'M', 1: 'R', 2: 'A', 3: 'X'}
label_dict = {0: 'G', 1: 'R',2: 'U'}

# %%
import pandas as pd

training = pd.read_pickle("../data/dataset_b_noisy_7_agents_training.pkl") 
test_comb = pd.read_pickle("../data/dataset_b_noisy_7_agents_test.pkl")

# %%
training.head()
# Out:
#           srcAS  destAS srcCC destCC  num_hops  \
# trid
# 1328731   14061   42999    US     TR        10
# 5183622  138062    3605    ID     GU         1
# 3258755   14061   24173    US     VN        10
# 2660757   16276    7171    FR     US        13
# 1730541   20473   12479    US     ES         7
#
#                                                        lat  \
# trid
# 1328731  [50.115520000000004, 50.115520000000004, 50.11...
# 5183622                                        [22.285521]
# 3258755  [40.714271999999994, 40.714271999999994, 40.71...
# 2660757  [0.0, 0.0, 0.0, 0.0, 1.28967, 43.296669, 48.86...
# 1730541  [48.860001000000004, 48.860001000000004, 48.86...
#
#                                                       long  \
# trid
# 1328731  [8.68417, 8.68417, 8.68417, 8.67185, 9.491, 8....
# 5183622                                         [114.1577]
# 3258755  [-74.005966, -74.005966, -74.005997, -122.3320...
# 2660757  [0.0, 0.0, 0.0, 0.0, 103.850098, 5.37639, 2.34...
# ...

# %%
test_comb.head()
# Out:
#          srcAS  destAS srcCC destCC  num_hops  \
# trid
# 4319757   8551    6147    IL     PE        12
# 3971404   8551    9121    IL     TR        13
# 4094951   8551    9583    IL     IN         8
# 1619804  20473  393396    US     US         8
# 1353363  14061   29465    US     NG        10
#
#                                                        lat  \
# trid
# 4319757  [32.080878999999996, 32.080878999999996, 50.11...
# 3971404  [32.080878999999996, 32.080878999999996, 32.08...
# 4094951  [32.080878999999996, 32.080878999999996, 32.08...
# 1619804  [48.860001000000004, 48.860001000000004, 48.86...
# 1353363  [50.115520000000004, 50.115520000000004, 50.11...
#
#                                                       long  \
# trid
# 4319757  [34.780571, 34.780571, 8.68417, 8.67185, 8.671...
# 3971404  [34.780571, 34.780571, 34.780571, -0.125740000...
# 4094951  [34.780571, 34.780571, 34.780571, -0.125740000...
# 1619804  [2.34444, 2.34444, 2.34444, 10.7487, 2.34444, ...
# ...

# %%
print(training['gpl'].value_counts())
print(training['gpo'].value_counts())
print(training['vf'].value_counts())
print(training['label_comb'].value_counts())
# Out:
# 0    2710641
# 1      86408
# 2       5752
# Name: gpl, dtype: int64
# 0    2782961
# 1      19338
# 2        502
# Name: gpo, dtype: int64
# 0    2727069
# 2      37986
# 1      37746
# Name: vf, dtype: int64
# 0    2666724
# 1     136077
# Name: label_comb, dtype: int64

# %%
print(test_comb['gpl'].value_counts())
print(test_comb['gpo'].value_counts())
print(test_comb['vf'].value_counts())
print(test_comb['label_comb'].value_counts())
# Out:
# 0    679078
# 1     21788
# 2      1517
# Name: gpl, dtype: int64
# 0    697340
# 1      4905
# 2       138
# Name: gpo, dtype: int64
# 0    683333
# 2      9542
# 1      9508
# Name: vf, dtype: int64
# 0    668035
# 1     34348
# Name: label_comb, dtype: int64
